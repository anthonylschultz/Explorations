# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#data-mining" data-toc-modified-id="data-mining-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>data mining</a></span></li><li><span><a href="#data-exploration" data-toc-modified-id="data-exploration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>data exploration</a></span></li></ul></div>

# %%
# import basics

from google.cloud import bigquery
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas_gbq
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # data mining

# %%
sql = """
SELECT *
FROM
  `bigquery-public-data.covid19_jhu_csse.confirmed_cases`
WHERE country_region = "US"
ORDER BY country_region DESC
"""
usa_cases = pandas_gbq.read_gbq(sql, project_id='liveramp-ts-bigquery')

# %%
usa_cases

# %% [markdown]
# # data exploration

# %%
usa_cases.info()

# %%
# drop unneeded columns
usa_cases = usa_cases.drop(['latitude', 'longitude', 'location_geom'], axis=1)

# %%
usa_cases
# Out:
#    _1_22_20  _1_23_20  _1_24_20  _1_25_20  _1_26_20  _1_27_20  _1_28_20  \
# 0         1         1         2         2         5         5         5
#
#    _1_29_20  _1_30_20  _1_31_20  ...  _6_11_20  _6_12_20  _6_13_20  _6_14_20  \
# 0         5         5         7  ...   2023590   2048986   2074526   2094058
#
#    _6_15_20  _6_16_20  _6_17_20  _6_18_20  _6_19_20  _6_20_20
# 0   2114026   2137731   2163290   2191052   2222579   2255119
#
# [1 rows x 151 columns]

# %%
usa_cases.plot()
# Out:
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:572: UserWarning: The handle <matplotlib.lines.Line2D object at 0x122683a50> has a label of '_1_22_20' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:572: UserWarning: The handle <matplotlib.lines.Line2D object at 0x122683bd0> has a label of '_1_23_20' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# /Users/aschul/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:572: UserWarning: The handle <matplotlib.lines.Line2D object at 0x1226c1450> has a label of '_1_24_20' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# ...
